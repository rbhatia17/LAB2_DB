# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-746a0228f9f8> in <module>()
# ----> 1 import CSV
#
# ModuleNotFoundError: No module named 'CSV'

# %%
import csv

# %%
cd desktop
# Out:
# /Users/rachitabhatia/Desktop

# %%
ls
# Out:
# Data.csv                  Homework.xls*             Sheet1.pdf*
# Fall 2017/                M!.jpg                    ~$Case 1.docx
# HW1.pdf*                  RachitaBhatia_resume.pdf  ~$se 1 strat.docx

# %%
#coverting a csv file into a dataframe
lab2= pd.read_csv('Data.csv')

# %%
#skipping the first empty row
with open("Data.csv",'r') as f, open("lab2.csv",'w') as f1:
    next(f) # skip header line
    for line in f:
        f1.write(line)

# %%
lab2= pd.read_csv('lab2.csv')

# %%
#skipping the row with the information about columns
lab2 = lab2.dropna(subset=['Entity'], how='any')

# %%
#Selecting only the columns that are required
lab2= lab2[['Entity','YEAR','records lost','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']]
lab2.columns = ['ENTITY','YEAR','RECORDS LOST','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']

# %%
#printing the lab2 file 
lab2
# Out:
#                                              ENTITY YEAR RECORDS LOST  \
# 1                                               AOL    0     92000000
# 2                         Automatic Data Processing    1       125000
# 3                                   Ameritrade Inc.    1       200000
# 4                                         Citigroup    1      3900000
# 5                       Cardsystems Solutions Inc.     1     40000000
# 6                                   Hewlett Packard    2       200000
# 7                        Countrywide Financial Corp    2      2600000
# 8                                              KDDI    2      4000000
# 9                        T-Mobile, Deutsche Telecom    2     17000000
# 10                                              AOL    2     20000000
# 11                           US Dept of Vet Affairs    2     26500000
# 12                                    Texas Lottery    3        89000
# 13     City and Hackney Teaching Primary Care Trust    3       160000
# 14                                          Gap Inc    3       800000
# 15                                     Compass Bank    3      1000000
# 16                                      Monster.com    3      1600000
# 17                         Driving Standards Agency    3      3000000
# 18                        Driving Standards Agency,    3      3000000
# 19             Hannaford Brothers Supermarket Chain    3      4200000
# 20                                    TD Ameritrade    3      6300000
# 21           Fidelity National Information Services    3      8500000
# 22                              Dai Nippon Printing    3      8637405
# 23                             UK Revenue & Customs    3     25000000
# 24                                     TK / TJ Maxx    3     94000000
# 25       Service Personnel and Veterans Agency (UK)    4        50500
# 26                              Stanford University    4        72000
# 27                                   UK Home Office    4        84000
# 28                                             AT&T    4       113000
# 29                                        Starbucks    4        97000
# 30                                     RBS Worldpay    4      1500000
# ..                                              ...  ...          ...
# 224                                       uTorrent    12        35000
# 225                                   Banner Health   12      3700000
# 226  Privatization Agency of the Republic of Serbia   12      5190396
# 227                               Quest Diagnostics   13        34000
# 228                                           Three   13       200000
# 229                                           Wonga   13       270000
# 230                                       PayAsUGym   13       300000
# 231                         Red Cross Blood Service   13       550000
# 232                                          DaFont   13       700000
# 233                                        Brazzers   13       790724
# 234                                        Snapchat   13      1700000
# 235                                            Bell   13      1900000
# 236                                      Cellebrite   13      3000000
# 237                                Clinton campaign   13      5000000
# 238                                       ClixSense   13      6600000
# 239                                       Lynda.com   13      9500000
# 240                                       Interpark   13     10000000
# 241                                          Zomato   13     17000000
# 242                                           Yahoo   13     32000000
# 243                                          Weebly   13     43000000
# 244                                     Dailymotion   13     85200000
# 245                           Friend Finder Network   13    412000000
# 246                                River City Media   13   1370000000
# 247                                       Telegram    13     15000000
# 248                                         Waterly   14      1000000
# 249                                             CEX   14      2000000
# 250                        Swedish Transport Agency   14      3000000
# 251                                       Instagram   14      6000000
# 252                                         Equifax   14    143000000
# 253                                         Spambot   14    711000000
#
#              ORGANISATION          METHOD OF LEAK DATA SENSITIVITY
# 1                     web              inside job                1
# 2               financial           poor security               20
# 3               financial    lost / stolen device               20
# 4               financial    lost / stolen device              300
# 5               financial                  hacked              300
# 6            tech, retail    lost / stolen device               20
# 7               financial              inside job              300
# 8                telecoms                  hacked                1
# 9                telecoms    lost / stolen device                1
# 10                    web  accidentally published                1
# 11   government, military    lost / stolen device               20
# 12             government              inside job               20
# 13             government    lost / stolen device               20
# 14                 retail    lost / stolen device               20
# 15              financial              inside job              300
# 16                    web                  hacked               20
# 17             government    lost / stolen device               20
# 18             government    lost / stolen device               20
# 19                 retail                  hacked              300
# 20              financial                  hacked                1
# 21              financial              inside job              300
# 22                 retail              inside job                1
# 23             government    lost / stolen device                1
# 24                 retail                  hacked              300
# 25             government    lost / stolen device               20
# 26               academic    lost / stolen device               20
# 27             government    lost / stolen device               20
# 28               telecoms    lost / stolen device                1
# 29                 retail    lost / stolen device               20
# 30              financial                  hacked               20
# ..                    ...                     ...              ...
# 224                   web                  hacked                1
# 225            healthcare                  hacked              300
# 226            government  accidentally published               20
# 227            healthcare                  hacked             4000
# 228              telecoms                  hacked               20
# 229             financial                  hacked            50000
# 230                   web                  hacked                1
# 231            healthcare  accidentally published             4000
# 232                   web                  hacked             4000
# 233                   web                  hacked             4000
# 234                   app                  hacked                1
# 235              telecoms                  hacked                1
# 236                  tech                  hacked               20
# 237            government                  hacked               20
# 238                   web                  hacked            50000
# 239                   web                  hacked                1
# 240                   web                  hacked               20
# 241                   web                  hacked             4000
# 242                   web                  hacked             4000
# 243                   web                  hacked             4000
# 244                   web                  hacked                1
# 245                   web                  hacked                1
# 246                   web  accidentally published               20
# 247                  tech                  hacked                1
# 248                   app           poor security              300
# 249                retail  accidentally published              300
# 250            government           poor security            50000
# 251                   web                  hacked                1
# 252             financial                  hacked            50000
# 253                   web           poor security             4000
#
# [253 rows x 6 columns]

# %%
lab2.loc[lab2['YEAR'] == '0', 'YEAR'] = 2004
lab2.loc[lab2['YEAR'] == '1', 'YEAR'] = 2005
lab2.loc[lab2['YEAR'] == '2', 'YEAR'] = 2006
lab2.loc[lab2['YEAR'] == '3', 'YEAR'] = 2007
lab2.loc[lab2['YEAR'] == '4', 'YEAR'] = 2008
lab2.loc[lab2['YEAR'] == '5', 'YEAR'] = 2009
lab2.loc[lab2['YEAR'] == '6', 'YEAR'] = 2010
lab2.loc[lab2['YEAR'] == '7', 'YEAR'] = 2011
lab2.loc[lab2['YEAR'] == '8', 'YEAR'] = 2012
lab2.loc[lab2['YEAR'] == '9', 'YEAR'] = 2013
lab2.loc[lab2['YEAR'] == '10', 'YEAR'] = 2014
lab2.loc[lab2['YEAR'] == '11', 'YEAR'] = 2015
lab2.loc[lab2['YEAR'] == '13', 'YEAR'] = 2017
lab2[lab2['YEAR'] == '14', 'YEAR'] = 'latest'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-5e38458a7fbf> in <module>()
#      12 lab2.loc[lab2['YEAR'] == '11', 'YEAR'] = 2015
#      13 lab2.loc[lab2['YEAR'] == '13', 'YEAR'] = 2017
# ---> 14 lab2[lab2['YEAR'] == '14', 'YEAR'] = 'latest'
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2692
#    2693         # broadcast across multiple columns if necessary
# -> 2694         if broadcast and key in self.columns and value.ndim == 1:
#    2695             if (not self.columns.is_unique or
#    2696                     isinstance(self.columns, MultiIndex)):
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    1588     @Appender(_index_shared_docs['__contains__'] % _index_doc_kwargs)
#    1589     def __contains__(self, key):
# -> 1590         hash(key)
#    1591         try:
#    1592             return key in self._engine
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#     875     def __hash__(self):
#     876         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 877                         ' hashed'.format(self.__class__.__name__))
#     878
#     879     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
#displaying the data types
lab2.dtypes
# Out:
# ENTITY              object
# YEAR                object
# RECORDS LOST        object
# ORGANISATION        object
# METHOD OF LEAK      object
# DATA SENSITIVITY    object
# dtype: object

# %%
lab2.loc[lab2['YEAR'] == '0', 'YEAR'] = 2004
lab2.loc[lab2['YEAR'] == '1', 'YEAR'] = 2005
lab2.loc[lab2['YEAR'] == '2', 'YEAR'] = 2006
lab2.loc[lab2['YEAR'] == '3', 'YEAR'] = 2007
lab2.loc[lab2['YEAR'] == '4', 'YEAR'] = 2008
lab2.loc[lab2['YEAR'] == '5', 'YEAR'] = 2009
lab2.loc[lab2['YEAR'] == '6', 'YEAR'] = 2010
lab2.loc[lab2['YEAR'] == '7', 'YEAR'] = 2011
lab2.loc[lab2['YEAR'] == '8', 'YEAR'] = 2012
lab2.loc[lab2['YEAR'] == '9', 'YEAR'] = 2013
lab2.loc[lab2['YEAR'] == '10', 'YEAR'] = 2014
lab2.loc[lab2['YEAR'] == '11', 'YEAR'] = 2015
lab2.loc[lab2['YEAR'] == '13', 'YEAR'] = 2017
lab2[lab2['YEAR'] == '14', 'YEAR'] = 'latest'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5e38458a7fbf> in <module>()
#      12 lab2.loc[lab2['YEAR'] == '11', 'YEAR'] = 2015
#      13 lab2.loc[lab2['YEAR'] == '13', 'YEAR'] = 2017
# ---> 14 lab2[lab2['YEAR'] == '14', 'YEAR'] = 'latest'
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2692
#    2693         # broadcast across multiple columns if necessary
# -> 2694         if broadcast and key in self.columns and value.ndim == 1:
#    2695             if (not self.columns.is_unique or
#    2696                     isinstance(self.columns, MultiIndex)):
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    1588     @Appender(_index_shared_docs['__contains__'] % _index_doc_kwargs)
#    1589     def __contains__(self, key):
# -> 1590         hash(key)
#    1591         try:
#    1592             return key in self._engine
#
# /Users/rachitabhatia/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#     875     def __hash__(self):
#     876         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 877                         ' hashed'.format(self.__class__.__name__))
#     878
#     879     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
#changing the year values to the original year
value_year = {"YEAR":{0:2004,1:2005,2:2006,3:2007,4:2008,5:2009,6:2010,7:2011,8:2012,9:2013,10:2014,11:2015,12:2016,13:2017,14:2018}}

# %%
lb2=lab2.replace(value_year)

# %%
lb2
# Out:
#                                              ENTITY  YEAR RECORDS LOST  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# 13     City and Hackney Teaching Primary Care Trust  2007       160000
# 14                                          Gap Inc  2007       800000
# 15                                     Compass Bank  2007      1000000
# 16                                      Monster.com  2007      1600000
# 17                         Driving Standards Agency  2007      3000000
# 18                        Driving Standards Agency,  2007      3000000
# 19             Hannaford Brothers Supermarket Chain  2007      4200000
# 20                                    TD Ameritrade  2007      6300000
# 21           Fidelity National Information Services  2007      8500000
# 22                              Dai Nippon Printing  2007      8637405
# 23                             UK Revenue & Customs  2007     25000000
# 24                                     TK / TJ Maxx  2007     94000000
# 25       Service Personnel and Veterans Agency (UK)  2008        50500
# 26                              Stanford University  2008        72000
# 27                                   UK Home Office  2008        84000
# 28                                             AT&T  2008       113000
# 29                                        Starbucks  2008        97000
# 30                                     RBS Worldpay  2008      1500000
# ..                                              ...   ...          ...
# 224                                       uTorrent     12        35000
# 225                                   Banner Health    12      3700000
# 226  Privatization Agency of the Republic of Serbia    12      5190396
# 227                               Quest Diagnostics  2017        34000
# 228                                           Three  2017       200000
# 229                                           Wonga  2017       270000
# 230                                       PayAsUGym  2017       300000
# 231                         Red Cross Blood Service  2017       550000
# 232                                          DaFont  2017       700000
# 233                                        Brazzers  2017       790724
# 234                                        Snapchat  2017      1700000
# 235                                            Bell  2017      1900000
# 236                                      Cellebrite  2017      3000000
# 237                                Clinton campaign  2017      5000000
# 238                                       ClixSense  2017      6600000
# 239                                       Lynda.com  2017      9500000
# 240                                       Interpark  2017     10000000
# 241                                          Zomato  2017     17000000
# 242                                           Yahoo  2017     32000000
# 243                                          Weebly  2017     43000000
# 244                                     Dailymotion  2017     85200000
# 245                           Friend Finder Network  2017    412000000
# 246                                River City Media  2017   1370000000
# 247                                       Telegram   2017     15000000
# 248                                         Waterly    14      1000000
# 249                                             CEX    14      2000000
# 250                        Swedish Transport Agency    14      3000000
# 251                                       Instagram    14      6000000
# 252                                         Equifax    14    143000000
# 253                                         Spambot    14    711000000
#
#              ORGANISATION          METHOD OF LEAK DATA SENSITIVITY
# 1                     web              inside job                1
# 2               financial           poor security               20
# 3               financial    lost / stolen device               20
# 4               financial    lost / stolen device              300
# 5               financial                  hacked              300
# 6            tech, retail    lost / stolen device               20
# 7               financial              inside job              300
# 8                telecoms                  hacked                1
# 9                telecoms    lost / stolen device                1
# 10                    web  accidentally published                1
# 11   government, military    lost / stolen device               20
# 12             government              inside job               20
# 13             government    lost / stolen device               20
# 14                 retail    lost / stolen device               20
# 15              financial              inside job              300
# 16                    web                  hacked               20
# 17             government    lost / stolen device               20
# 18             government    lost / stolen device               20
# 19                 retail                  hacked              300
# 20              financial                  hacked                1
# 21              financial              inside job              300
# 22                 retail              inside job                1
# 23             government    lost / stolen device                1
# 24                 retail                  hacked              300
# 25             government    lost / stolen device               20
# 26               academic    lost / stolen device               20
# 27             government    lost / stolen device               20
# 28               telecoms    lost / stolen device                1
# 29                 retail    lost / stolen device               20
# 30              financial                  hacked               20
# ..                    ...                     ...              ...
# 224                   web                  hacked                1
# 225            healthcare                  hacked              300
# 226            government  accidentally published               20
# 227            healthcare                  hacked             4000
# 228              telecoms                  hacked               20
# 229             financial                  hacked            50000
# 230                   web                  hacked                1
# 231            healthcare  accidentally published             4000
# 232                   web                  hacked             4000
# 233                   web                  hacked             4000
# 234                   app                  hacked                1
# 235              telecoms                  hacked                1
# 236                  tech                  hacked               20
# 237            government                  hacked               20
# 238                   web                  hacked            50000
# 239                   web                  hacked                1
# 240                   web                  hacked               20
# 241                   web                  hacked             4000
# 242                   web                  hacked             4000
# 243                   web                  hacked             4000
# 244                   web                  hacked                1
# 245                   web                  hacked                1
# 246                   web  accidentally published               20
# 247                  tech                  hacked                1
# 248                   app           poor security              300
# 249                retail  accidentally published              300
# 250            government           poor security            50000
# 251                   web                  hacked                1
# 252             financial                  hacked            50000
# 253                   web           poor security             4000
#
# [253 rows x 6 columns]

# %%
value_year = {"YEAR":{0:2004,1:2005,2:2006,3:2007,4:2008,5:2009,6:2010,7:2011,8:2012,9:2013,10:2014,11:2015,12:2016,13:2017,14:2018}}

# %%
lb2_db=lab2.replace(value_year)

# %%
lb2_db
# Out:
#                                              ENTITY  YEAR RECORDS LOST  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# 13     City and Hackney Teaching Primary Care Trust  2007       160000
# 14                                          Gap Inc  2007       800000
# 15                                     Compass Bank  2007      1000000
# 16                                      Monster.com  2007      1600000
# 17                         Driving Standards Agency  2007      3000000
# 18                        Driving Standards Agency,  2007      3000000
# 19             Hannaford Brothers Supermarket Chain  2007      4200000
# 20                                    TD Ameritrade  2007      6300000
# 21           Fidelity National Information Services  2007      8500000
# 22                              Dai Nippon Printing  2007      8637405
# 23                             UK Revenue & Customs  2007     25000000
# 24                                     TK / TJ Maxx  2007     94000000
# 25       Service Personnel and Veterans Agency (UK)  2008        50500
# 26                              Stanford University  2008        72000
# 27                                   UK Home Office  2008        84000
# 28                                             AT&T  2008       113000
# 29                                        Starbucks  2008        97000
# 30                                     RBS Worldpay  2008      1500000
# ..                                              ...   ...          ...
# 224                                       uTorrent     12        35000
# 225                                   Banner Health    12      3700000
# 226  Privatization Agency of the Republic of Serbia    12      5190396
# 227                               Quest Diagnostics  2017        34000
# 228                                           Three  2017       200000
# 229                                           Wonga  2017       270000
# 230                                       PayAsUGym  2017       300000
# 231                         Red Cross Blood Service  2017       550000
# 232                                          DaFont  2017       700000
# 233                                        Brazzers  2017       790724
# 234                                        Snapchat  2017      1700000
# 235                                            Bell  2017      1900000
# 236                                      Cellebrite  2017      3000000
# 237                                Clinton campaign  2017      5000000
# 238                                       ClixSense  2017      6600000
# 239                                       Lynda.com  2017      9500000
# 240                                       Interpark  2017     10000000
# 241                                          Zomato  2017     17000000
# 242                                           Yahoo  2017     32000000
# 243                                          Weebly  2017     43000000
# 244                                     Dailymotion  2017     85200000
# 245                           Friend Finder Network  2017    412000000
# 246                                River City Media  2017   1370000000
# 247                                       Telegram   2017     15000000
# 248                                         Waterly    14      1000000
# 249                                             CEX    14      2000000
# 250                        Swedish Transport Agency    14      3000000
# 251                                       Instagram    14      6000000
# 252                                         Equifax    14    143000000
# 253                                         Spambot    14    711000000
#
#              ORGANISATION          METHOD OF LEAK DATA SENSITIVITY
# 1                     web              inside job                1
# 2               financial           poor security               20
# 3               financial    lost / stolen device               20
# 4               financial    lost / stolen device              300
# 5               financial                  hacked              300
# 6            tech, retail    lost / stolen device               20
# 7               financial              inside job              300
# 8                telecoms                  hacked                1
# 9                telecoms    lost / stolen device                1
# 10                    web  accidentally published                1
# 11   government, military    lost / stolen device               20
# 12             government              inside job               20
# 13             government    lost / stolen device               20
# 14                 retail    lost / stolen device               20
# 15              financial              inside job              300
# 16                    web                  hacked               20
# 17             government    lost / stolen device               20
# 18             government    lost / stolen device               20
# 19                 retail                  hacked              300
# 20              financial                  hacked                1
# 21              financial              inside job              300
# 22                 retail              inside job                1
# 23             government    lost / stolen device                1
# 24                 retail                  hacked              300
# 25             government    lost / stolen device               20
# 26               academic    lost / stolen device               20
# 27             government    lost / stolen device               20
# 28               telecoms    lost / stolen device                1
# 29                 retail    lost / stolen device               20
# 30              financial                  hacked               20
# ..                    ...                     ...              ...
# 224                   web                  hacked                1
# 225            healthcare                  hacked              300
# 226            government  accidentally published               20
# 227            healthcare                  hacked             4000
# 228              telecoms                  hacked               20
# 229             financial                  hacked            50000
# 230                   web                  hacked                1
# 231            healthcare  accidentally published             4000
# 232                   web                  hacked             4000
# 233                   web                  hacked             4000
# 234                   app                  hacked                1
# 235              telecoms                  hacked                1
# 236                  tech                  hacked               20
# 237            government                  hacked               20
# 238                   web                  hacked            50000
# 239                   web                  hacked                1
# 240                   web                  hacked               20
# 241                   web                  hacked             4000
# 242                   web                  hacked             4000
# 243                   web                  hacked             4000
# 244                   web                  hacked                1
# 245                   web                  hacked                1
# 246                   web  accidentally published               20
# 247                  tech                  hacked                1
# 248                   app           poor security              300
# 249                retail  accidentally published              300
# 250            government           poor security            50000
# 251                   web                  hacked                1
# 252             financial                  hacked            50000
# 253                   web           poor security             4000
#
# [253 rows x 6 columns]

# %%
lb2_db.to_csv('lb2_2017.csv')

# %%
#changing the values of sensitivity to actual data
lb2_db.loc[lb2_db['DATA SENSITIVITY'] == '1', 'DATA SENSITIVITY'] = 'Just email address/Online information'
lb2_db.loc[lb2_db['DATA SENSITIVITY'] == '20', 'DATA SENSITIVITY'] = 'SSN/Personal details'
lb2_db.loc[lb2_db['DATA SENSITIVITY'] == '300', 'DATA SENSITIVITY'] = 'Credit card information'
lb2_db.loc[lb2_db['DATA SENSITIVITY'] == '4000', 'DATA SENSITIVITY'] = 'Email password/Health records'
lb2_db.loc[lb2_db['DATA SENSITIVITY'] == '50000', 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
lb2_db
# Out:
#                                              ENTITY  YEAR RECORDS LOST  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# 13     City and Hackney Teaching Primary Care Trust  2007       160000
# 14                                          Gap Inc  2007       800000
# 15                                     Compass Bank  2007      1000000
# 16                                      Monster.com  2007      1600000
# 17                         Driving Standards Agency  2007      3000000
# 18                        Driving Standards Agency,  2007      3000000
# 19             Hannaford Brothers Supermarket Chain  2007      4200000
# 20                                    TD Ameritrade  2007      6300000
# 21           Fidelity National Information Services  2007      8500000
# 22                              Dai Nippon Printing  2007      8637405
# 23                             UK Revenue & Customs  2007     25000000
# 24                                     TK / TJ Maxx  2007     94000000
# 25       Service Personnel and Veterans Agency (UK)  2008        50500
# 26                              Stanford University  2008        72000
# 27                                   UK Home Office  2008        84000
# 28                                             AT&T  2008       113000
# 29                                        Starbucks  2008        97000
# 30                                     RBS Worldpay  2008      1500000
# ..                                              ...   ...          ...
# 224                                       uTorrent     12        35000
# 225                                   Banner Health    12      3700000
# 226  Privatization Agency of the Republic of Serbia    12      5190396
# 227                               Quest Diagnostics  2017        34000
# 228                                           Three  2017       200000
# 229                                           Wonga  2017       270000
# 230                                       PayAsUGym  2017       300000
# 231                         Red Cross Blood Service  2017       550000
# 232                                          DaFont  2017       700000
# 233                                        Brazzers  2017       790724
# 234                                        Snapchat  2017      1700000
# 235                                            Bell  2017      1900000
# 236                                      Cellebrite  2017      3000000
# 237                                Clinton campaign  2017      5000000
# 238                                       ClixSense  2017      6600000
# 239                                       Lynda.com  2017      9500000
# 240                                       Interpark  2017     10000000
# 241                                          Zomato  2017     17000000
# 242                                           Yahoo  2017     32000000
# 243                                          Weebly  2017     43000000
# 244                                     Dailymotion  2017     85200000
# 245                           Friend Finder Network  2017    412000000
# 246                                River City Media  2017   1370000000
# 247                                       Telegram   2017     15000000
# 248                                         Waterly    14      1000000
# 249                                             CEX    14      2000000
# 250                        Swedish Transport Agency    14      3000000
# 251                                       Instagram    14      6000000
# 252                                         Equifax    14    143000000
# 253                                         Spambot    14    711000000
#
#              ORGANISATION          METHOD OF LEAK  \
# 1                     web              inside job
# 2               financial           poor security
# 3               financial    lost / stolen device
# 4               financial    lost / stolen device
# 5               financial                  hacked
# 6            tech, retail    lost / stolen device
# 7               financial              inside job
# 8                telecoms                  hacked
# 9                telecoms    lost / stolen device
# 10                    web  accidentally published
# 11   government, military    lost / stolen device
# 12             government              inside job
# 13             government    lost / stolen device
# 14                 retail    lost / stolen device
# 15              financial              inside job
# 16                    web                  hacked
# 17             government    lost / stolen device
# 18             government    lost / stolen device
# 19                 retail                  hacked
# 20              financial                  hacked
# 21              financial              inside job
# 22                 retail              inside job
# 23             government    lost / stolen device
# 24                 retail                  hacked
# 25             government    lost / stolen device
# 26               academic    lost / stolen device
# 27             government    lost / stolen device
# 28               telecoms    lost / stolen device
# 29                 retail    lost / stolen device
# 30              financial                  hacked
# ..                    ...                     ...
# 224                   web                  hacked
# 225            healthcare                  hacked
# 226            government  accidentally published
# 227            healthcare                  hacked
# 228              telecoms                  hacked
# 229             financial                  hacked
# 230                   web                  hacked
# 231            healthcare  accidentally published
# 232                   web                  hacked
# 233                   web                  hacked
# 234                   app                  hacked
# 235              telecoms                  hacked
# 236                  tech                  hacked
# 237            government                  hacked
# 238                   web                  hacked
# 239                   web                  hacked
# 240                   web                  hacked
# 241                   web                  hacked
# 242                   web                  hacked
# 243                   web                  hacked
# 244                   web                  hacked
# 245                   web                  hacked
# 246                   web  accidentally published
# 247                  tech                  hacked
# 248                   app           poor security
# 249                retail  accidentally published
# 250            government           poor security
# 251                   web                  hacked
# 252             financial                  hacked
# 253                   web           poor security
#
#                           DATA SENSITIVITY
# 1    Just email address/Online information
# 2                     SSN/Personal details
# 3                     SSN/Personal details
# 4                  Credit card information
# 5                  Credit card information
# 6                     SSN/Personal details
# 7                  Credit card information
# 8    Just email address/Online information
# 9    Just email address/Online information
# 10   Just email address/Online information
# 11                    SSN/Personal details
# 12                    SSN/Personal details
# 13                    SSN/Personal details
# 14                    SSN/Personal details
# 15                 Credit card information
# 16                    SSN/Personal details
# 17                    SSN/Personal details
# 18                    SSN/Personal details
# 19                 Credit card information
# 20   Just email address/Online information
# 21                 Credit card information
# 22   Just email address/Online information
# 23   Just email address/Online information
# 24                 Credit card information
# 25                    SSN/Personal details
# 26                    SSN/Personal details
# 27                    SSN/Personal details
# 28   Just email address/Online information
# 29                    SSN/Personal details
# 30                    SSN/Personal details
# ..                                     ...
# 224  Just email address/Online information
# 225                Credit card information
# 226                   SSN/Personal details
# 227          Email password/Health records
# 228                   SSN/Personal details
# 229              Full bank account details
# 230  Just email address/Online information
# 231          Email password/Health records
# 232          Email password/Health records
# 233          Email password/Health records
# 234  Just email address/Online information
# 235  Just email address/Online information
# 236                   SSN/Personal details
# 237                   SSN/Personal details
# 238              Full bank account details
# 239  Just email address/Online information
# 240                   SSN/Personal details
# 241          Email password/Health records
# 242          Email password/Health records
# 243          Email password/Health records
# 244  Just email address/Online information
# 245  Just email address/Online information
# 246                   SSN/Personal details
# 247  Just email address/Online information
# 248                Credit card information
# 249                Credit card information
# 250              Full bank account details
# 251  Just email address/Online information
# 252              Full bank account details
# 253          Email password/Health records
#
# [253 rows x 6 columns]

# %%
#Saving the updated file as a CSV file
lb2_db.to_csv('lb2_2017.csv')

# %%
lb2_2015 = pd.read_csv('Data_2015.csv')

# %%
with open("Data_2015.csv",'r') as f, open("lb2_2015.csv",'w') as f1:
    next(f) # skip header line
    for line in f:
        f1.write(line)

# %%
lb2_2015 = pd.read_csv('lb2_2015.csv')

# %%
lb2_2015 = lb2_2015.dropna(subset=['Entity'], how='any')

# %%
from itertools import islice
with open("lb2_db.csv") as myfile:
    head = list(islice(myfile, 3))
print (head)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-892264f13d56> in <module>()
#       1 from itertools import islice
# ----> 2 with open("lb2_db.csv") as myfile:
#       3     head = list(islice(myfile, 3))
#       4 print (head)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lb2_db.csv'

# %%
lb2_2015= lb2_2015[['Entity','YEAR','records lost','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']]
lb2_2015.columns = ['ENTITY','YEAR','RECORDS LOST','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']

# %%
lb2_2015
# Out:
#                                              ENTITY YEAR  \
# 1                                               AOL    0
# 2                                   Ameritrade Inc.    1
# 3                         Automatic Data Processing    1
# 4                       Cardsystems Solutions Inc.     1
# 5                                         Citigroup    1
# 6                                               AOL    2
# 7                        Countrywide Financial Corp    2
# 8                                   Hewlett Packard    2
# 9                                              KDDI    2
# 10                       T-Mobile, Deutsche Telecom    2
# 11                           US Dept of Vet Affairs    2
# 12     City and Hackney Teaching Primary Care Trust    3
# 13                                     Compass Bank    3
# 14                              Dai Nippon Printing    3
# 15                         Driving Standards Agency    3
# 16                        Driving Standards Agency,    3
# 17           Fidelity National Information Services    3
# 18                                          Gap Inc    3
# 19             Hannaford Brothers Supermarket Chain    3
# 20                                      Monster.com    3
# 21                                    TD Ameritrade    3
# 22                                    Texas Lottery    3
# 23                                     TK / TJ Maxx    3
# 24                             UK Revenue & Customs    3
# 25                                             AT&T    4
# 26                                    Auction.co.kr    4
# 27                   BNY Mellon Shareowner Services    4
# 28                      Chile Ministry Of Education    4
# 29                    Data Processors International    4
# 30                                        GS Caltex    4
# ..                                              ...  ...
# 182                             Experian / T-mobile   12
# 183                              CarPhone Warehouse   12
# 184                               AshleyMadison.com   12
# 185  US Office of Personnel Management (2nd Breach)   12
# 186                                             IRS   12
# 187                             Adult Friend Finder   12
# 188                                            MSpy   12
# 189               Australian Immigration Department   12
# 190                                 British Airways   12
# 191                                        LastPass   12
# 192                                    Hacking Team   12
# 193                                        TalkTalk   12
# 194                            Securus Technologies   12
# 195                                     Invest Bank   12
# 196                                        Kromtech   12
# 197                                           VTech   12
# 198                                          Sanrio   12
# 199                               US Voter Database   12
# 200                               Time Warner Cable   12
# 201                                          Anthem   12
# 202                              Premera Blue Cross   12
# 203                                        Snapchat   12
# 204                                        Code.org   12
# 205                                         Verizon   12
# 206                                 Mossack Fonseca   12
# 207                    Turkish citizenship database   12
# 208                       National Childbirth Trust   12
# 209                               Syrian government   12
# 210            Philippines’ Commission on Elections   12
# 211                                       PF Changs  NaN
#
#                   RECORDS LOST          ORGANISATION          METHOD OF LEAK  \
# 1                   92,000,000                   web      inside job, hacked
# 2                      200,000             financial     lost / stolen media
# 3                      125,000             financial           poor security
# 4                   40,000,000             financial                  hacked
# 5                    3,900,000             financial    lost / stolen media
# 6                   20,000,000                   web  accidentally published
# 7                    2,600,000             financial              inside job
# 8                      200,000          tech, retail     lost / stolen media
# 9                    4,000,000              telecoms                  hacked
# 10                  17,000,000              telecoms    lost / stolen media
# 11                  26,500,000  government, military  lost / stolen computer
# 12                     160,000            government     lost / stolen media
# 13                   1,000,000             financial              inside job
# 14                   8,637,405                retail              inside job
# 15                   3,000,000            government     lost / stolen media
# 16                   3,000,000            government     lost / stolen media
# 17                   8,500,000             financial              inside job
# 18                     800,000                retail  lost / stolen computer
# 19                   4,200,000                retail                  hacked
# 20                   1,600,000                   web                  hacked
# 21                   6,300,000             financial                  hacked
# 22                      89,000            government              inside job
# 23                  94,000,000                retail                  hacked
# 24                  25,000,000            government    lost / stolen media
# 25                     113,000              telecoms  lost / stolen computer
# 26                  18,000,000                   web                  hacked
# 27                  12,500,000             financial    lost / stolen media
# 28                   6,000,000            government  accidentally published
# 29                   5,000,000             financial                  hacked
# 30                  11,100,000                energy              inside job
# ..                         ...                   ...                     ...
# 182                 15,000,000                   web                  hacked
# 183                  2,700,000                   web                  hacked
# 184                 37,000,000                   web                  hacked
# 185                 14,000,000            government                  hacked
# 186                    100,000            government           poor security
# 187                  3,900,000                   web                  hacked
# 188                    400,000                  tech                  hacked
# 189                  "unknown"            government  accidentally published
# 190        "tens of thousands"                retail                  hacked
# 191                  7 million                   web                  hacked
# 192                  "unknown"                   web                  hacked
# 193                    157,000                   web                  hacked
# 194                 70 million                   web                  hacked
# 195                     40,000               banking                  hacked
# 196                 13 million                   web                    leak
# 197               11.6 million                   web           poor security
# 198                3.3 million                   web     configuration error
# 199                191 million                   web     configuration error
# 200                    320,000                   web                 unknown
# 201                 80,000,000                   web                  hacked
# 202                 11,000,000                   web                  hacked
# 203                unannounced                   web                  hacked
# 204  10 (not million, just 10)                   web           poor security
# 205                    100,000                   web                  hacked
# 206                 11,500,000              law firm                    leak
# 207                 49,611,709            government                    leak
# 208                     15,000                   web                  hacked
# 209                    274,477            government                  hacked
# 210                 55,000,000            government                  hacked
# 211                    282,000                   NaN                     NaN
#
#     DATA SENSITIVITY
# 1                  1
# 2                 20
# 3                 20
# 4                300
# 5                300
# 6                  1
# 7                300
# 8                 20
# 9                  1
# 10                 1
# 11                20
# 12                20
# 13               300
# 14                 1
# 15                20
# 16                20
# 17               300
# 18                20
# 19               300
# 20                20
# 21                 1
# 22                20
# 23               300
# 24                 1
# 25                 1
# 26               300
# 27                 1
# 28                 1
# 29                 1
# 30                20
# ..               ...
# 182                3
# 183                5
# 184                4
# 185                3
# 186                1
# 187                1
# 188                3
# 189                5
# 190                1
# 191                4
# 192                5
# 193                2
# 194                5
# 195                5
# 196                1
# 197                5
# 198                2
# 199                2
# 200                1
# 201                4
# 202                4
# 203                5
# 204                1
# 205                1
# 206                5
# 207                2
# 208                1
# 209                1
# 210                5
# 211                3
#
# [211 rows x 6 columns]

# %%
value_year1 = {"YEAR":{0:2004,1:2005,2:2006,3:2007,4:2008,5:2009,6:2010,7:2011,8:2012,9:2013,10:2014,11:2015,12:2016,13:2017,14:2018}}

# %%
lb2_db2015=lb2_2015.replace(value_year)

# %%
lb2_db2015
# Out:
#                                              ENTITY YEAR  \
# 1                                               AOL    0
# 2                                   Ameritrade Inc.    1
# 3                         Automatic Data Processing    1
# 4                       Cardsystems Solutions Inc.     1
# 5                                         Citigroup    1
# 6                                               AOL    2
# 7                        Countrywide Financial Corp    2
# 8                                   Hewlett Packard    2
# 9                                              KDDI    2
# 10                       T-Mobile, Deutsche Telecom    2
# 11                           US Dept of Vet Affairs    2
# 12     City and Hackney Teaching Primary Care Trust    3
# 13                                     Compass Bank    3
# 14                              Dai Nippon Printing    3
# 15                         Driving Standards Agency    3
# 16                        Driving Standards Agency,    3
# 17           Fidelity National Information Services    3
# 18                                          Gap Inc    3
# 19             Hannaford Brothers Supermarket Chain    3
# 20                                      Monster.com    3
# 21                                    TD Ameritrade    3
# 22                                    Texas Lottery    3
# 23                                     TK / TJ Maxx    3
# 24                             UK Revenue & Customs    3
# 25                                             AT&T    4
# 26                                    Auction.co.kr    4
# 27                   BNY Mellon Shareowner Services    4
# 28                      Chile Ministry Of Education    4
# 29                    Data Processors International    4
# 30                                        GS Caltex    4
# ..                                              ...  ...
# 182                             Experian / T-mobile   12
# 183                              CarPhone Warehouse   12
# 184                               AshleyMadison.com   12
# 185  US Office of Personnel Management (2nd Breach)   12
# 186                                             IRS   12
# 187                             Adult Friend Finder   12
# 188                                            MSpy   12
# 189               Australian Immigration Department   12
# 190                                 British Airways   12
# 191                                        LastPass   12
# 192                                    Hacking Team   12
# 193                                        TalkTalk   12
# 194                            Securus Technologies   12
# 195                                     Invest Bank   12
# 196                                        Kromtech   12
# 197                                           VTech   12
# 198                                          Sanrio   12
# 199                               US Voter Database   12
# 200                               Time Warner Cable   12
# 201                                          Anthem   12
# 202                              Premera Blue Cross   12
# 203                                        Snapchat   12
# 204                                        Code.org   12
# 205                                         Verizon   12
# 206                                 Mossack Fonseca   12
# 207                    Turkish citizenship database   12
# 208                       National Childbirth Trust   12
# 209                               Syrian government   12
# 210            Philippines’ Commission on Elections   12
# 211                                       PF Changs  NaN
#
#                   RECORDS LOST          ORGANISATION          METHOD OF LEAK  \
# 1                   92,000,000                   web      inside job, hacked
# 2                      200,000             financial     lost / stolen media
# 3                      125,000             financial           poor security
# 4                   40,000,000             financial                  hacked
# 5                    3,900,000             financial    lost / stolen media
# 6                   20,000,000                   web  accidentally published
# 7                    2,600,000             financial              inside job
# 8                      200,000          tech, retail     lost / stolen media
# 9                    4,000,000              telecoms                  hacked
# 10                  17,000,000              telecoms    lost / stolen media
# 11                  26,500,000  government, military  lost / stolen computer
# 12                     160,000            government     lost / stolen media
# 13                   1,000,000             financial              inside job
# 14                   8,637,405                retail              inside job
# 15                   3,000,000            government     lost / stolen media
# 16                   3,000,000            government     lost / stolen media
# 17                   8,500,000             financial              inside job
# 18                     800,000                retail  lost / stolen computer
# 19                   4,200,000                retail                  hacked
# 20                   1,600,000                   web                  hacked
# 21                   6,300,000             financial                  hacked
# 22                      89,000            government              inside job
# 23                  94,000,000                retail                  hacked
# 24                  25,000,000            government    lost / stolen media
# 25                     113,000              telecoms  lost / stolen computer
# 26                  18,000,000                   web                  hacked
# 27                  12,500,000             financial    lost / stolen media
# 28                   6,000,000            government  accidentally published
# 29                   5,000,000             financial                  hacked
# 30                  11,100,000                energy              inside job
# ..                         ...                   ...                     ...
# 182                 15,000,000                   web                  hacked
# 183                  2,700,000                   web                  hacked
# 184                 37,000,000                   web                  hacked
# 185                 14,000,000            government                  hacked
# 186                    100,000            government           poor security
# 187                  3,900,000                   web                  hacked
# 188                    400,000                  tech                  hacked
# 189                  "unknown"            government  accidentally published
# 190        "tens of thousands"                retail                  hacked
# 191                  7 million                   web                  hacked
# 192                  "unknown"                   web                  hacked
# 193                    157,000                   web                  hacked
# 194                 70 million                   web                  hacked
# 195                     40,000               banking                  hacked
# 196                 13 million                   web                    leak
# 197               11.6 million                   web           poor security
# 198                3.3 million                   web     configuration error
# 199                191 million                   web     configuration error
# 200                    320,000                   web                 unknown
# 201                 80,000,000                   web                  hacked
# 202                 11,000,000                   web                  hacked
# 203                unannounced                   web                  hacked
# 204  10 (not million, just 10)                   web           poor security
# 205                    100,000                   web                  hacked
# 206                 11,500,000              law firm                    leak
# 207                 49,611,709            government                    leak
# 208                     15,000                   web                  hacked
# 209                    274,477            government                  hacked
# 210                 55,000,000            government                  hacked
# 211                    282,000                   NaN                     NaN
#
#     DATA SENSITIVITY
# 1                  1
# 2                 20
# 3                 20
# 4                300
# 5                300
# 6                  1
# 7                300
# 8                 20
# 9                  1
# 10                 1
# 11                20
# 12                20
# 13               300
# 14                 1
# 15                20
# 16                20
# 17               300
# 18                20
# 19               300
# 20                20
# 21                 1
# 22                20
# 23               300
# 24                 1
# 25                 1
# 26               300
# 27                 1
# 28                 1
# 29                 1
# 30                20
# ..               ...
# 182                3
# 183                5
# 184                4
# 185                3
# 186                1
# 187                1
# 188                3
# 189                5
# 190                1
# 191                4
# 192                5
# 193                2
# 194                5
# 195                5
# 196                1
# 197                5
# 198                2
# 199                2
# 200                1
# 201                4
# 202                4
# 203                5
# 204                1
# 205                1
# 206                5
# 207                2
# 208                1
# 209                1
# 210                5
# 211                3
#
# [211 rows x 6 columns]

# %%
lb2_2015 = pd.read_csv('lb2_2015.csv')

# %%
lb2_2015 = lb2_2015.dropna(subset=['Entity'], how='any')

# %%
lb2_2015.dtypes
# Out:
# Entity                         object
# alternative name               object
# story                          object
# YEAR                           object
# records lost                   object
# ORGANISATION                   object
# METHOD OF LEAK                 object
# interesting story              object
# NO OF RECORDS STOLEN           object
# DATA SENSITIVITY               object
# UNUSED                        float64
# UNUSED.1                      float64
# Exclude                        object
# Unnamed: 13                   float64
# 1st source link                object
# 2nd source link                object
# 3rd source                     object
# source name                    object
# UNUSED.2                       object
# UNUSED.3                      float64
# UNUSED.4                      float64
# UNUSED.5                      float64
# UNUSED.6                      float64
# UNUSED.7                      float64
# Unnamed: 24                   float64
# Link to individual study      float64
# Link to individual study.1    float64
# Link to individual study.2    float64
# Link to individual study.3    float64
# Link to individual study.4    float64
# Link to individual study.5    float64
# Link to individual study.6    float64
# Link to individual study.7    float64
# Link to individual study.8    float64
# Link to individual study.9    float64
# dtype: object

# %%
lb2_2015= lb2_2015[['Entity','YEAR','records lost','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']]
lb2_2015.columns = ['ENTITY','YEAR','RECORDS LOST','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']

# %%
lb2_2015.dtypes
# Out:
# ENTITY              object
# YEAR                object
# RECORDS LOST        object
# ORGANISATION        object
# METHOD OF LEAK      object
# DATA SENSITIVITY    object
# dtype: object

# %%
"""
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '1', 'DATA SENSITIVITY'] = 'Just email address/Online information'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '20', 'DATA SENSITIVITY'] = 'SSN/Personal details'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '300', 'DATA SENSITIVITY'] = 'Credit card information'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '4000', 'DATA SENSITIVITY'] = 'Email password/Health records'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '50000', 'DATA SENSITIVITY'] = 'Full bank account details'
"""
# Out:
# "\nlb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '1', 'DATA SENSITIVITY'] = 'Just email address/Online information'\nlb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '20', 'DATA SENSITIVITY'] = 'SSN/Personal details'\nlb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '300', 'DATA SENSITIVITY'] = 'Credit card information'\nlb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '4000', 'DATA SENSITIVITY'] = 'Email password/Health records'\nlb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '50000', 'DATA SENSITIVITY'] = 'Full bank account details'\n"

# %% [markdown]
# lb2_2015

# %%
lb2_2015
# Out:
#                                              ENTITY YEAR  \
# 1                                               AOL    0
# 2                                   Ameritrade Inc.    1
# 3                         Automatic Data Processing    1
# 4                       Cardsystems Solutions Inc.     1
# 5                                         Citigroup    1
# 6                                               AOL    2
# 7                        Countrywide Financial Corp    2
# 8                                   Hewlett Packard    2
# 9                                              KDDI    2
# 10                       T-Mobile, Deutsche Telecom    2
# 11                           US Dept of Vet Affairs    2
# 12     City and Hackney Teaching Primary Care Trust    3
# 13                                     Compass Bank    3
# 14                              Dai Nippon Printing    3
# 15                         Driving Standards Agency    3
# 16                        Driving Standards Agency,    3
# 17           Fidelity National Information Services    3
# 18                                          Gap Inc    3
# 19             Hannaford Brothers Supermarket Chain    3
# 20                                      Monster.com    3
# 21                                    TD Ameritrade    3
# 22                                    Texas Lottery    3
# 23                                     TK / TJ Maxx    3
# 24                             UK Revenue & Customs    3
# 25                                             AT&T    4
# 26                                    Auction.co.kr    4
# 27                   BNY Mellon Shareowner Services    4
# 28                      Chile Ministry Of Education    4
# 29                    Data Processors International    4
# 30                                        GS Caltex    4
# ..                                              ...  ...
# 182                             Experian / T-mobile   12
# 183                              CarPhone Warehouse   12
# 184                               AshleyMadison.com   12
# 185  US Office of Personnel Management (2nd Breach)   12
# 186                                             IRS   12
# 187                             Adult Friend Finder   12
# 188                                            MSpy   12
# 189               Australian Immigration Department   12
# 190                                 British Airways   12
# 191                                        LastPass   12
# 192                                    Hacking Team   12
# 193                                        TalkTalk   12
# 194                            Securus Technologies   12
# 195                                     Invest Bank   12
# 196                                        Kromtech   12
# 197                                           VTech   12
# 198                                          Sanrio   12
# 199                               US Voter Database   12
# 200                               Time Warner Cable   12
# 201                                          Anthem   12
# 202                              Premera Blue Cross   12
# 203                                        Snapchat   12
# 204                                        Code.org   12
# 205                                         Verizon   12
# 206                                 Mossack Fonseca   12
# 207                    Turkish citizenship database   12
# 208                       National Childbirth Trust   12
# 209                               Syrian government   12
# 210            Philippines’ Commission on Elections   12
# 211                                       PF Changs  NaN
#
#                   RECORDS LOST          ORGANISATION          METHOD OF LEAK  \
# 1                   92,000,000                   web      inside job, hacked
# 2                      200,000             financial     lost / stolen media
# 3                      125,000             financial           poor security
# 4                   40,000,000             financial                  hacked
# 5                    3,900,000             financial    lost / stolen media
# 6                   20,000,000                   web  accidentally published
# 7                    2,600,000             financial              inside job
# 8                      200,000          tech, retail     lost / stolen media
# 9                    4,000,000              telecoms                  hacked
# 10                  17,000,000              telecoms    lost / stolen media
# 11                  26,500,000  government, military  lost / stolen computer
# 12                     160,000            government     lost / stolen media
# 13                   1,000,000             financial              inside job
# 14                   8,637,405                retail              inside job
# 15                   3,000,000            government     lost / stolen media
# 16                   3,000,000            government     lost / stolen media
# 17                   8,500,000             financial              inside job
# 18                     800,000                retail  lost / stolen computer
# 19                   4,200,000                retail                  hacked
# 20                   1,600,000                   web                  hacked
# 21                   6,300,000             financial                  hacked
# 22                      89,000            government              inside job
# 23                  94,000,000                retail                  hacked
# 24                  25,000,000            government    lost / stolen media
# 25                     113,000              telecoms  lost / stolen computer
# 26                  18,000,000                   web                  hacked
# 27                  12,500,000             financial    lost / stolen media
# 28                   6,000,000            government  accidentally published
# 29                   5,000,000             financial                  hacked
# 30                  11,100,000                energy              inside job
# ..                         ...                   ...                     ...
# 182                 15,000,000                   web                  hacked
# 183                  2,700,000                   web                  hacked
# 184                 37,000,000                   web                  hacked
# 185                 14,000,000            government                  hacked
# 186                    100,000            government           poor security
# 187                  3,900,000                   web                  hacked
# 188                    400,000                  tech                  hacked
# 189                  "unknown"            government  accidentally published
# 190        "tens of thousands"                retail                  hacked
# 191                  7 million                   web                  hacked
# 192                  "unknown"                   web                  hacked
# 193                    157,000                   web                  hacked
# 194                 70 million                   web                  hacked
# 195                     40,000               banking                  hacked
# 196                 13 million                   web                    leak
# 197               11.6 million                   web           poor security
# 198                3.3 million                   web     configuration error
# 199                191 million                   web     configuration error
# 200                    320,000                   web                 unknown
# 201                 80,000,000                   web                  hacked
# 202                 11,000,000                   web                  hacked
# 203                unannounced                   web                  hacked
# 204  10 (not million, just 10)                   web           poor security
# 205                    100,000                   web                  hacked
# 206                 11,500,000              law firm                    leak
# 207                 49,611,709            government                    leak
# 208                     15,000                   web                  hacked
# 209                    274,477            government                  hacked
# 210                 55,000,000            government                  hacked
# 211                    282,000                   NaN                     NaN
#
#     DATA SENSITIVITY
# 1                  1
# 2                 20
# 3                 20
# 4                300
# 5                300
# 6                  1
# 7                300
# 8                 20
# 9                  1
# 10                 1
# 11                20
# 12                20
# 13               300
# 14                 1
# 15                20
# 16                20
# 17               300
# 18                20
# 19               300
# 20                20
# 21                 1
# 22                20
# 23               300
# 24                 1
# 25                 1
# 26               300
# 27                 1
# 28                 1
# 29                 1
# 30                20
# ..               ...
# 182                3
# 183                5
# 184                4
# 185                3
# 186                1
# 187                1
# 188                3
# 189                5
# 190                1
# 191                4
# 192                5
# 193                2
# 194                5
# 195                5
# 196                1
# 197                5
# 198                2
# 199                2
# 200                1
# 201                4
# 202                4
# 203                5
# 204                1
# 205                1
# 206                5
# 207                2
# 208                1
# 209                1
# 210                5
# 211                3
#
# [211 rows x 6 columns]

# %%
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '1', 'DATA SENSITIVITY'] = 'Just email address/Online information'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '20', 'DATA SENSITIVITY'] = 'SSN/Personal details'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '300', 'DATA SENSITIVITY'] = 'Credit card information'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '4000', 'DATA SENSITIVITY'] = 'Email password/Health records'
lb2_2015.loc[lb2_2015['DATA SENSITIVITY'] == '50000', 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
lb2_2015
# Out:
#                                              ENTITY YEAR  \
# 1                                               AOL    0
# 2                                   Ameritrade Inc.    1
# 3                         Automatic Data Processing    1
# 4                       Cardsystems Solutions Inc.     1
# 5                                         Citigroup    1
# 6                                               AOL    2
# 7                        Countrywide Financial Corp    2
# 8                                   Hewlett Packard    2
# 9                                              KDDI    2
# 10                       T-Mobile, Deutsche Telecom    2
# 11                           US Dept of Vet Affairs    2
# 12     City and Hackney Teaching Primary Care Trust    3
# 13                                     Compass Bank    3
# 14                              Dai Nippon Printing    3
# 15                         Driving Standards Agency    3
# 16                        Driving Standards Agency,    3
# 17           Fidelity National Information Services    3
# 18                                          Gap Inc    3
# 19             Hannaford Brothers Supermarket Chain    3
# 20                                      Monster.com    3
# 21                                    TD Ameritrade    3
# 22                                    Texas Lottery    3
# 23                                     TK / TJ Maxx    3
# 24                             UK Revenue & Customs    3
# 25                                             AT&T    4
# 26                                    Auction.co.kr    4
# 27                   BNY Mellon Shareowner Services    4
# 28                      Chile Ministry Of Education    4
# 29                    Data Processors International    4
# 30                                        GS Caltex    4
# ..                                              ...  ...
# 182                             Experian / T-mobile   12
# 183                              CarPhone Warehouse   12
# 184                               AshleyMadison.com   12
# 185  US Office of Personnel Management (2nd Breach)   12
# 186                                             IRS   12
# 187                             Adult Friend Finder   12
# 188                                            MSpy   12
# 189               Australian Immigration Department   12
# 190                                 British Airways   12
# 191                                        LastPass   12
# 192                                    Hacking Team   12
# 193                                        TalkTalk   12
# 194                            Securus Technologies   12
# 195                                     Invest Bank   12
# 196                                        Kromtech   12
# 197                                           VTech   12
# 198                                          Sanrio   12
# 199                               US Voter Database   12
# 200                               Time Warner Cable   12
# 201                                          Anthem   12
# 202                              Premera Blue Cross   12
# 203                                        Snapchat   12
# 204                                        Code.org   12
# 205                                         Verizon   12
# 206                                 Mossack Fonseca   12
# 207                    Turkish citizenship database   12
# 208                       National Childbirth Trust   12
# 209                               Syrian government   12
# 210            Philippines’ Commission on Elections   12
# 211                                       PF Changs  NaN
#
#                   RECORDS LOST          ORGANISATION          METHOD OF LEAK  \
# 1                   92,000,000                   web      inside job, hacked
# 2                      200,000             financial     lost / stolen media
# 3                      125,000             financial           poor security
# 4                   40,000,000             financial                  hacked
# 5                    3,900,000             financial    lost / stolen media
# 6                   20,000,000                   web  accidentally published
# 7                    2,600,000             financial              inside job
# 8                      200,000          tech, retail     lost / stolen media
# 9                    4,000,000              telecoms                  hacked
# 10                  17,000,000              telecoms    lost / stolen media
# 11                  26,500,000  government, military  lost / stolen computer
# 12                     160,000            government     lost / stolen media
# 13                   1,000,000             financial              inside job
# 14                   8,637,405                retail              inside job
# 15                   3,000,000            government     lost / stolen media
# 16                   3,000,000            government     lost / stolen media
# 17                   8,500,000             financial              inside job
# 18                     800,000                retail  lost / stolen computer
# 19                   4,200,000                retail                  hacked
# 20                   1,600,000                   web                  hacked
# 21                   6,300,000             financial                  hacked
# 22                      89,000            government              inside job
# 23                  94,000,000                retail                  hacked
# 24                  25,000,000            government    lost / stolen media
# 25                     113,000              telecoms  lost / stolen computer
# 26                  18,000,000                   web                  hacked
# 27                  12,500,000             financial    lost / stolen media
# 28                   6,000,000            government  accidentally published
# 29                   5,000,000             financial                  hacked
# 30                  11,100,000                energy              inside job
# ..                         ...                   ...                     ...
# 182                 15,000,000                   web                  hacked
# 183                  2,700,000                   web                  hacked
# 184                 37,000,000                   web                  hacked
# 185                 14,000,000            government                  hacked
# 186                    100,000            government           poor security
# 187                  3,900,000                   web                  hacked
# 188                    400,000                  tech                  hacked
# 189                  "unknown"            government  accidentally published
# 190        "tens of thousands"                retail                  hacked
# 191                  7 million                   web                  hacked
# 192                  "unknown"                   web                  hacked
# 193                    157,000                   web                  hacked
# 194                 70 million                   web                  hacked
# 195                     40,000               banking                  hacked
# 196                 13 million                   web                    leak
# 197               11.6 million                   web           poor security
# 198                3.3 million                   web     configuration error
# 199                191 million                   web     configuration error
# 200                    320,000                   web                 unknown
# 201                 80,000,000                   web                  hacked
# 202                 11,000,000                   web                  hacked
# 203                unannounced                   web                  hacked
# 204  10 (not million, just 10)                   web           poor security
# 205                    100,000                   web                  hacked
# 206                 11,500,000              law firm                    leak
# 207                 49,611,709            government                    leak
# 208                     15,000                   web                  hacked
# 209                    274,477            government                  hacked
# 210                 55,000,000            government                  hacked
# 211                    282,000                   NaN                     NaN
#
#                           DATA SENSITIVITY
# 1    Just email address/Online information
# 2                     SSN/Personal details
# 3                     SSN/Personal details
# 4                  Credit card information
# 5                  Credit card information
# 6    Just email address/Online information
# 7                  Credit card information
# 8                     SSN/Personal details
# 9    Just email address/Online information
# 10   Just email address/Online information
# 11                    SSN/Personal details
# 12                    SSN/Personal details
# 13                 Credit card information
# 14   Just email address/Online information
# 15                    SSN/Personal details
# 16                    SSN/Personal details
# 17                 Credit card information
# 18                    SSN/Personal details
# 19                 Credit card information
# 20                    SSN/Personal details
# 21   Just email address/Online information
# 22                    SSN/Personal details
# 23                 Credit card information
# 24   Just email address/Online information
# 25   Just email address/Online information
# 26                 Credit card information
# 27   Just email address/Online information
# 28   Just email address/Online information
# 29   Just email address/Online information
# 30                    SSN/Personal details
# ..                                     ...
# 182                                      3
# 183                                      5
# 184                                      4
# 185                                      3
# 186  Just email address/Online information
# 187  Just email address/Online information
# 188                                      3
# 189                                      5
# 190  Just email address/Online information
# 191                                      4
# 192                                      5
# 193                                      2
# 194                                      5
# 195                                      5
# 196  Just email address/Online information
# 197                                      5
# 198                                      2
# 199                                      2
# 200  Just email address/Online information
# 201                                      4
# 202                                      4
# 203                                      5
# 204  Just email address/Online information
# 205  Just email address/Online information
# 206                                      5
# 207                                      2
# 208  Just email address/Online information
# 209  Just email address/Online information
# 210                                      5
# 211                                      3
#
# [211 rows x 6 columns]

# %%
lb2_2015.loc[lb2_2015['YEAR'] == '0', 'YEAR'] = 2004
lb2_2015.loc[lb2_2015['YEAR'] == '1', 'YEAR'] = 2005
lb2_2015.loc[lb2_2015['YEAR'] == '2', 'YEAR'] = 2006
lb2_2015.loc[lb2_2015['YEAR'] == '3', 'YEAR'] = 2007
lb2_2015.loc[lb2_2015['YEAR'] == '4', 'YEAR'] = 2008
lb2_2015.loc[lb2_2015['YEAR'] == '5', 'YEAR'] = 2009
lb2_2015.loc[lb2_2015['YEAR'] == '6', 'YEAR'] = 2010
lb2_2015.loc[lb2_2015['YEAR'] == '7', 'YEAR'] = 2011
lb2_2015.loc[lb2_2015['YEAR'] == '8', 'YEAR'] = 2012
lb2_2015.loc[lb2_2015['YEAR'] == '9', 'YEAR'] = 2013
lb2_2015.loc[lb2_2015['YEAR'] == '10', 'YEAR'] = 2014
lb2_2015.loc[lb2_2015['YEAR'] == '11', 'YEAR'] = 2015
lb2_2015.loc[lb2_2015['YEAR'] == '12', 'YEAR'] = 2016
lb2_2015.loc[lb2_2015['YEAR'] == '13', 'YEAR'] = 2017
lb2_2015.loc[lb2_2015['YEAR'] == '14', 'YEAR'] = 'latest'

# %%
lb2_2015
# Out:
#                                              ENTITY  YEAR  \
# 1                                               AOL  2004
# 2                                   Ameritrade Inc.  2005
# 3                         Automatic Data Processing  2005
# 4                       Cardsystems Solutions Inc.   2005
# 5                                         Citigroup  2005
# 6                                               AOL  2006
# 7                        Countrywide Financial Corp  2006
# 8                                   Hewlett Packard  2006
# 9                                              KDDI  2006
# 10                       T-Mobile, Deutsche Telecom  2006
# 11                           US Dept of Vet Affairs  2006
# 12     City and Hackney Teaching Primary Care Trust  2007
# 13                                     Compass Bank  2007
# 14                              Dai Nippon Printing  2007
# 15                         Driving Standards Agency  2007
# 16                        Driving Standards Agency,  2007
# 17           Fidelity National Information Services  2007
# 18                                          Gap Inc  2007
# 19             Hannaford Brothers Supermarket Chain  2007
# 20                                      Monster.com  2007
# 21                                    TD Ameritrade  2007
# 22                                    Texas Lottery  2007
# 23                                     TK / TJ Maxx  2007
# 24                             UK Revenue & Customs  2007
# 25                                             AT&T  2008
# 26                                    Auction.co.kr  2008
# 27                   BNY Mellon Shareowner Services  2008
# 28                      Chile Ministry Of Education  2008
# 29                    Data Processors International  2008
# 30                                        GS Caltex  2008
# ..                                              ...   ...
# 182                             Experian / T-mobile  2016
# 183                              CarPhone Warehouse  2016
# 184                               AshleyMadison.com  2016
# 185  US Office of Personnel Management (2nd Breach)  2016
# 186                                             IRS  2016
# 187                             Adult Friend Finder  2016
# 188                                            MSpy  2016
# 189               Australian Immigration Department  2016
# 190                                 British Airways  2016
# 191                                        LastPass  2016
# 192                                    Hacking Team  2016
# 193                                        TalkTalk  2016
# 194                            Securus Technologies  2016
# 195                                     Invest Bank  2016
# 196                                        Kromtech  2016
# 197                                           VTech  2016
# 198                                          Sanrio  2016
# 199                               US Voter Database  2016
# 200                               Time Warner Cable  2016
# 201                                          Anthem  2016
# 202                              Premera Blue Cross  2016
# 203                                        Snapchat  2016
# 204                                        Code.org  2016
# 205                                         Verizon  2016
# 206                                 Mossack Fonseca  2016
# 207                    Turkish citizenship database  2016
# 208                       National Childbirth Trust  2016
# 209                               Syrian government  2016
# 210            Philippines’ Commission on Elections  2016
# 211                                       PF Changs   NaN
#
#                   RECORDS LOST          ORGANISATION          METHOD OF LEAK  \
# 1                   92,000,000                   web      inside job, hacked
# 2                      200,000             financial     lost / stolen media
# 3                      125,000             financial           poor security
# 4                   40,000,000             financial                  hacked
# 5                    3,900,000             financial    lost / stolen media
# 6                   20,000,000                   web  accidentally published
# 7                    2,600,000             financial              inside job
# 8                      200,000          tech, retail     lost / stolen media
# 9                    4,000,000              telecoms                  hacked
# 10                  17,000,000              telecoms    lost / stolen media
# 11                  26,500,000  government, military  lost / stolen computer
# 12                     160,000            government     lost / stolen media
# 13                   1,000,000             financial              inside job
# 14                   8,637,405                retail              inside job
# 15                   3,000,000            government     lost / stolen media
# 16                   3,000,000            government     lost / stolen media
# 17                   8,500,000             financial              inside job
# 18                     800,000                retail  lost / stolen computer
# 19                   4,200,000                retail                  hacked
# 20                   1,600,000                   web                  hacked
# 21                   6,300,000             financial                  hacked
# 22                      89,000            government              inside job
# 23                  94,000,000                retail                  hacked
# 24                  25,000,000            government    lost / stolen media
# 25                     113,000              telecoms  lost / stolen computer
# 26                  18,000,000                   web                  hacked
# 27                  12,500,000             financial    lost / stolen media
# 28                   6,000,000            government  accidentally published
# 29                   5,000,000             financial                  hacked
# 30                  11,100,000                energy              inside job
# ..                         ...                   ...                     ...
# 182                 15,000,000                   web                  hacked
# 183                  2,700,000                   web                  hacked
# 184                 37,000,000                   web                  hacked
# 185                 14,000,000            government                  hacked
# 186                    100,000            government           poor security
# 187                  3,900,000                   web                  hacked
# 188                    400,000                  tech                  hacked
# 189                  "unknown"            government  accidentally published
# 190        "tens of thousands"                retail                  hacked
# 191                  7 million                   web                  hacked
# 192                  "unknown"                   web                  hacked
# 193                    157,000                   web                  hacked
# 194                 70 million                   web                  hacked
# 195                     40,000               banking                  hacked
# 196                 13 million                   web                    leak
# 197               11.6 million                   web           poor security
# 198                3.3 million                   web     configuration error
# 199                191 million                   web     configuration error
# 200                    320,000                   web                 unknown
# 201                 80,000,000                   web                  hacked
# 202                 11,000,000                   web                  hacked
# 203                unannounced                   web                  hacked
# 204  10 (not million, just 10)                   web           poor security
# 205                    100,000                   web                  hacked
# 206                 11,500,000              law firm                    leak
# 207                 49,611,709            government                    leak
# 208                     15,000                   web                  hacked
# 209                    274,477            government                  hacked
# 210                 55,000,000            government                  hacked
# 211                    282,000                   NaN                     NaN
#
#                           DATA SENSITIVITY
# 1    Just email address/Online information
# 2                     SSN/Personal details
# 3                     SSN/Personal details
# 4                  Credit card information
# 5                  Credit card information
# 6    Just email address/Online information
# 7                  Credit card information
# 8                     SSN/Personal details
# 9    Just email address/Online information
# 10   Just email address/Online information
# 11                    SSN/Personal details
# 12                    SSN/Personal details
# 13                 Credit card information
# 14   Just email address/Online information
# 15                    SSN/Personal details
# 16                    SSN/Personal details
# 17                 Credit card information
# 18                    SSN/Personal details
# 19                 Credit card information
# 20                    SSN/Personal details
# 21   Just email address/Online information
# 22                    SSN/Personal details
# 23                 Credit card information
# 24   Just email address/Online information
# 25   Just email address/Online information
# 26                 Credit card information
# 27   Just email address/Online information
# 28   Just email address/Online information
# 29   Just email address/Online information
# 30                    SSN/Personal details
# ..                                     ...
# 182                                      3
# 183                                      5
# 184                                      4
# 185                                      3
# 186  Just email address/Online information
# 187  Just email address/Online information
# 188                                      3
# 189                                      5
# 190  Just email address/Online information
# 191                                      4
# 192                                      5
# 193                                      2
# 194                                      5
# 195                                      5
# 196  Just email address/Online information
# 197                                      5
# 198                                      2
# 199                                      2
# 200  Just email address/Online information
# 201                                      4
# 202                                      4
# 203                                      5
# 204  Just email address/Online information
# 205  Just email address/Online information
# 206                                      5
# 207                                      2
# 208  Just email address/Online information
# 209  Just email address/Online information
# 210                                      5
# 211                                      3
#
# [211 rows x 6 columns]

# %%
#removing the rows with no value for the year column
lb2_2015 = lb2_2015.dropna(axis=0, subset=['YEAR'], how='any')

# %%
lb2_2015
# Out:
#                                              ENTITY  YEAR  \
# 1                                               AOL  2004
# 2                                   Ameritrade Inc.  2005
# 3                         Automatic Data Processing  2005
# 4                       Cardsystems Solutions Inc.   2005
# 5                                         Citigroup  2005
# 6                                               AOL  2006
# 7                        Countrywide Financial Corp  2006
# 8                                   Hewlett Packard  2006
# 9                                              KDDI  2006
# 10                       T-Mobile, Deutsche Telecom  2006
# 11                           US Dept of Vet Affairs  2006
# 12     City and Hackney Teaching Primary Care Trust  2007
# 13                                     Compass Bank  2007
# 14                              Dai Nippon Printing  2007
# 15                         Driving Standards Agency  2007
# 16                        Driving Standards Agency,  2007
# 17           Fidelity National Information Services  2007
# 18                                          Gap Inc  2007
# 19             Hannaford Brothers Supermarket Chain  2007
# 20                                      Monster.com  2007
# 21                                    TD Ameritrade  2007
# 22                                    Texas Lottery  2007
# 23                                     TK / TJ Maxx  2007
# 24                             UK Revenue & Customs  2007
# 25                                             AT&T  2008
# 26                                    Auction.co.kr  2008
# 27                   BNY Mellon Shareowner Services  2008
# 28                      Chile Ministry Of Education  2008
# 29                    Data Processors International  2008
# 30                                        GS Caltex  2008
# ..                                              ...   ...
# 181                                   Sony Pictures  2015
# 182                             Experian / T-mobile  2016
# 183                              CarPhone Warehouse  2016
# 184                               AshleyMadison.com  2016
# 185  US Office of Personnel Management (2nd Breach)  2016
# 186                                             IRS  2016
# 187                             Adult Friend Finder  2016
# 188                                            MSpy  2016
# 189               Australian Immigration Department  2016
# 190                                 British Airways  2016
# 191                                        LastPass  2016
# 192                                    Hacking Team  2016
# 193                                        TalkTalk  2016
# 194                            Securus Technologies  2016
# 195                                     Invest Bank  2016
# 196                                        Kromtech  2016
# 197                                           VTech  2016
# 198                                          Sanrio  2016
# 199                               US Voter Database  2016
# 200                               Time Warner Cable  2016
# 201                                          Anthem  2016
# 202                              Premera Blue Cross  2016
# 203                                        Snapchat  2016
# 204                                        Code.org  2016
# 205                                         Verizon  2016
# 206                                 Mossack Fonseca  2016
# 207                    Turkish citizenship database  2016
# 208                       National Childbirth Trust  2016
# 209                               Syrian government  2016
# 210            Philippines’ Commission on Elections  2016
#
#                   RECORDS LOST          ORGANISATION          METHOD OF LEAK  \
# 1                   92,000,000                   web      inside job, hacked
# 2                      200,000             financial     lost / stolen media
# 3                      125,000             financial           poor security
# 4                   40,000,000             financial                  hacked
# 5                    3,900,000             financial    lost / stolen media
# 6                   20,000,000                   web  accidentally published
# 7                    2,600,000             financial              inside job
# 8                      200,000          tech, retail     lost / stolen media
# 9                    4,000,000              telecoms                  hacked
# 10                  17,000,000              telecoms    lost / stolen media
# 11                  26,500,000  government, military  lost / stolen computer
# 12                     160,000            government     lost / stolen media
# 13                   1,000,000             financial              inside job
# 14                   8,637,405                retail              inside job
# 15                   3,000,000            government     lost / stolen media
# 16                   3,000,000            government     lost / stolen media
# 17                   8,500,000             financial              inside job
# 18                     800,000                retail  lost / stolen computer
# 19                   4,200,000                retail                  hacked
# 20                   1,600,000                   web                  hacked
# 21                   6,300,000             financial                  hacked
# 22                      89,000            government              inside job
# 23                  94,000,000                retail                  hacked
# 24                  25,000,000            government    lost / stolen media
# 25                     113,000              telecoms  lost / stolen computer
# 26                  18,000,000                   web                  hacked
# 27                  12,500,000             financial    lost / stolen media
# 28                   6,000,000            government  accidentally published
# 29                   5,000,000             financial                  hacked
# 30                  11,100,000                energy              inside job
# ..                         ...                   ...                     ...
# 181             100 terrabytes                 media                  hacked
# 182                 15,000,000                   web                  hacked
# 183                  2,700,000                   web                  hacked
# 184                 37,000,000                   web                  hacked
# 185                 14,000,000            government                  hacked
# 186                    100,000            government           poor security
# 187                  3,900,000                   web                  hacked
# 188                    400,000                  tech                  hacked
# 189                  "unknown"            government  accidentally published
# 190        "tens of thousands"                retail                  hacked
# 191                  7 million                   web                  hacked
# 192                  "unknown"                   web                  hacked
# 193                    157,000                   web                  hacked
# 194                 70 million                   web                  hacked
# 195                     40,000               banking                  hacked
# 196                 13 million                   web                    leak
# 197               11.6 million                   web           poor security
# 198                3.3 million                   web     configuration error
# 199                191 million                   web     configuration error
# 200                    320,000                   web                 unknown
# 201                 80,000,000                   web                  hacked
# 202                 11,000,000                   web                  hacked
# 203                unannounced                   web                  hacked
# 204  10 (not million, just 10)                   web           poor security
# 205                    100,000                   web                  hacked
# 206                 11,500,000              law firm                    leak
# 207                 49,611,709            government                    leak
# 208                     15,000                   web                  hacked
# 209                    274,477            government                  hacked
# 210                 55,000,000            government                  hacked
#
#                           DATA SENSITIVITY
# 1    Just email address/Online information
# 2                     SSN/Personal details
# 3                     SSN/Personal details
# 4                  Credit card information
# 5                  Credit card information
# 6    Just email address/Online information
# 7                  Credit card information
# 8                     SSN/Personal details
# 9    Just email address/Online information
# 10   Just email address/Online information
# 11                    SSN/Personal details
# 12                    SSN/Personal details
# 13                 Credit card information
# 14   Just email address/Online information
# 15                    SSN/Personal details
# 16                    SSN/Personal details
# 17                 Credit card information
# 18                    SSN/Personal details
# 19                 Credit card information
# 20                    SSN/Personal details
# 21   Just email address/Online information
# 22                    SSN/Personal details
# 23                 Credit card information
# 24   Just email address/Online information
# 25   Just email address/Online information
# 26                 Credit card information
# 27   Just email address/Online information
# 28   Just email address/Online information
# 29   Just email address/Online information
# 30                    SSN/Personal details
# ..                                     ...
# 181                                      4
# 182                                      3
# 183                                      5
# 184                                      4
# 185                                      3
# 186  Just email address/Online information
# 187  Just email address/Online information
# 188                                      3
# 189                                      5
# 190  Just email address/Online information
# 191                                      4
# 192                                      5
# 193                                      2
# 194                                      5
# 195                                      5
# 196  Just email address/Online information
# 197                                      5
# 198                                      2
# 199                                      2
# 200  Just email address/Online information
# 201                                      4
# 202                                      4
# 203                                      5
# 204  Just email address/Online information
# 205  Just email address/Online information
# 206                                      5
# 207                                      2
# 208  Just email address/Online information
# 209  Just email address/Online information
# 210                                      5
#
# [210 rows x 6 columns]

# %%
lb2_2015.to_csv('Data_2015.csv')

# %%
lb2_2013 = pd.read_csv('Data_2013.csv')

# %%
with open("Data_2013.csv",'r') as f, open("lb2_2013.csv",'w') as f1:
    next(f) # skip header line
    for line in f:
        f1.write(line)

# %%
lb2_2013 = pd.read_csv('lb2_2013.csv')

# %%
lb2_2013 = lb2_2013.dropna(subset=['Entity'], how='any')

# %%
lb2_2013.dtypes
# Out:
# Entity                         object
# alternative name               object
# story                          object
# YEAR                           object
# records lost                   object
# ORGANISATION                   object
# METHOD OF LEAK                 object
# interesting story              object
# NO OF RECORDS STOLEN           object
# DATA SENSITIVITY               object
# UNUSED                        float64
# UNUSED.1                      float64
# Exclude                        object
# Unnamed: 13                   float64
# 1st source link                object
# 2nd source link                object
# 3rd source                     object
# source name                    object
# UNUSED.2                       object
# UNUSED.3                      float64
# UNUSED.4                      float64
# UNUSED.5                      float64
# UNUSED.6                      float64
# UNUSED.7                      float64
# Unnamed: 24                   float64
# Link to individual study      float64
# Link to individual study.1    float64
# Link to individual study.2    float64
# Link to individual study.3    float64
# Link to individual study.4    float64
# Link to individual study.5    float64
# Link to individual study.6    float64
# Link to individual study.7    float64
# Link to individual study.8    float64
# Link to individual study.9    float64
# dtype: object

# %%
lb2_2013= lb2_2013[['Entity','YEAR','records lost','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']]
lb2_2013.columns = ['ENTITY','YEAR','RECORDS LOST','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']

# %%
lb2_2013
# Out:
#                                               ENTITY YEAR RECORDS LOST  \
# 1                             Accendo Insurance Co.     7      175,350
# 2                         Affinity Health Plan, Inc.    5      344,579
# 3             Ankle & foot Center of Tampa Bay, Inc.    6      156,000
# 4                                                AOL    0   92,000,000
# 5                                                AOL    2   20,000,000
# 6                                              Apple    8  12,367,232
# 7                                              Apple    9      275,000
# 8                                               AT&T    4      113,000
# 9                                               AT&T    6      114,000
# 10                                     Auction.co.kr    4   18,000,000
# 11                         Automatic Data Processing    1      125,000
# 12                                       AvMed, Inc.    5    1,220,000
# 13                                           Betfair    6    2,300,000
# 14                             Bethesda Game Studios    7      200,000
# 15                                          Blizzard    8   14,000,000
# 16               Blue Cross Blue Shield of Tennessee    5    1,023,209
# 17                    BNY Mellon Shareowner Services    4   12,500,000
# 18   California Department of Child Support Services    8      800,000
# 19                       Cardsystems Solutions Inc.     1   40,000,000
# 20                     Central Hudson Gas & Electric    9      110,000
# 21                             CheckFree Corporation    5    5,000,000
# 22                       Chile Ministry Of Education    4    6,000,000
# 23                                         Citigroup    1    3,900,000
# 24                                         Citigroup    7      360,083
# 25                               Colorado government    6      105,470
# 26                                      Compass Bank    3    1,000,000
# 27                        Countrywide Financial Corp    2    2,600,000
# 28                   Crescent Health Inc., Walgreens    9      100,000
# 29                               Dai Nippon Printing    3    8,637,405
# 30                     Data Processors International    4    5,000,000
# ..                                               ...  ...          ...
# 94                                TerraCom & YourTel    9      170,000
# 95                                     Texas Lottery    3       89,000
# 96                               Three Iranian banks    8    3,000,000
# 97                                      TK / TJ Maxx    3   94,000,000
# 98                                           Tricare    7    4,901,432
# 99                              Triple-S Salud, Inc.    6      398,000
# 100                                          Twitter    9      250,000
# 101                                          UbiSoft    9      unknown
# 102                                           Ubuntu    9    2,000,000
# 103                             UK Revenue & Customs    3   25,000,000
# 104                University of California Berkeley    5      160,000
# 105                              University of Miami    4    2,100,000
# 106           University of Utah Hospitals & Clinics    4    2,200,000
# 107              University of Wisconsin - Milwaukee    7       73,000
# 108                                          US Army    7       50,000
# 109                               US Dept of Defense    5       72,000
# 110                           US Dept of Vet Affairs    2   26,500,000
# 111             US Federal Reserve Bank of Cleveland    6      400,000
# 112                               US Law Enforcement    7      123,461
# 113                                      US Military    5   76,000,000
# 114                                      US Military    6      260,000
# 115                                US National Guard    5      131,000
# 116                         Virginia Dept. Of Health    5    8,257,378
# 117         Virginia Prescription Monitoring Program    5      531,400
# 118                                  Washington Post    7    1,270,000
# 119                    Washington State court system    9      160,000
# 120                                  Writerspace.com    7       62,000
# 121                                            Yahoo    8      450,000
# 122                                            Yahoo    9   22,000,000
# 123                                  Yale University    6       43,000
#
#                ORGANISATION          METHOD OF LEAK DATA SENSITIVITY
# 1                healthcare           poor security                4
# 2                healthcare    lost / stolen media                 4
# 3                healthcare                  hacked                4
# 4                       web      inside job, hacked                1
# 5                       web  accidentally published                1
# 6              tech, retail  accidentally published                2
# 7                      tech                  hacked                1
# 8                  telecoms  lost / stolen computer                1
# 9                  telecoms                  hacked                1
# 10                      web                  hacked                3
# 11                financial           poor security                2
# 12               healthcare  lost / stolen computer             2, 4
# 13                      web                  hacked                3
# 14                   gaming                  hacked                1
# 15                   gaming                  hacked                2
# 16               healthcare    lost / stolen media                 2
# 17                financial    lost / stolen media                 1
# 18               government    lost / stolen media                 2
# 19                financial                  hacked                3
# 20                   energy                  hacked                3
# 21                financial                  hacked                1
# 22               government  accidentally published                1
# 23                financial    lost / stolen media                 3
# 24                financial                  hacked                3
# 25               healthcare  lost / stolen computer                2
# 26                financial              inside job                3
# 27                financial              inside job                3
# 28               healthcare  lost / stolen computer                4
# 29                   retail              inside job                1
# 30                financial                  hacked                1
# ..                      ...                     ...              ...
# 94                 telecoms  accidentally published                2
# 95               government              inside job                2
# 96                financial                  hacked                5
# 97                   retail                  hacked                3
# 98     military, healthcare  lost / stolen computer                4
# 99               healthcare     lost / stolen media                4
# 100                     web                 hacked                 1
# 101                  gaming                  hacked                2
# 102                    tech                  hacked                3
# 103              government    lost / stolen media                 1
# 104                academic                  hacked                3
# 105                academic  lost / stolen computer             3, 4
# 106                academic     lost / stolen media                4
# 107                academic                  hacked                2
# 108                military  accidentally published                1
# 109                military    lost / stolen media                 2
# 110    government, military  lost / stolen computer                2
# 111               financial                  hacked                3
# 112              government  accidentally published                3
# 113                military    lost / stolen media                 2
# 114                military  lost / stolen computer                5
# 115                military  lost / stolen computer                2
# 116  government, healthcare                  hacked                4
# 117              healthcare                  hacked                2
# 118                   media                  hacked                2
# 119              government                  hacked                2
# 120                     web                  hacked                1
# 121               tech, web                  hacked                1
# 122               tech, web                  hacked                1
# 123                academic  accidentally published                2
#
# [122 rows x 6 columns]

# %%
lb2_2013.dtypes
# Out:
# ENTITY              object
# YEAR                object
# RECORDS LOST        object
# ORGANISATION        object
# METHOD OF LEAK      object
# DATA SENSITIVITY    object
# dtype: object

# %%
lb2_2013.loc[lb2_2013['YEAR'] == '0', 'YEAR'] = 2004
lb2_2013.loc[lb2_2013['YEAR'] == '1', 'YEAR'] = 2005
lb2_2013.loc[lb2_2013['YEAR'] == '2', 'YEAR'] = 2006
lb2_2013.loc[lb2_2013['YEAR'] == '3', 'YEAR'] = 2007
lb2_2013.loc[lb2_2013['YEAR'] == '4', 'YEAR'] = 2008
lb2_2013.loc[lb2_2013['YEAR'] == '5', 'YEAR'] = 2009
lb2_2013.loc[lb2_2013['YEAR'] == '6', 'YEAR'] = 2010
lb2_2013.loc[lb2_2013['YEAR'] == '7', 'YEAR'] = 2011
lb2_2013.loc[lb2_2013['YEAR'] == '8', 'YEAR'] = 2012
lb2_2013.loc[lb2_2013['YEAR'] == '9', 'YEAR'] = 2013
lb2_2013.loc[lb2_2013['YEAR'] == '10', 'YEAR'] = 2014
lb2_2013.loc[lb2_2013['YEAR'] == '11', 'YEAR'] = 2015
lb2_2013.loc[lb2_2013['YEAR'] == '12', 'YEAR'] = 2016
lb2_2013.loc[lb2_2013['YEAR'] == '13', 'YEAR'] = 2017
lb2_2013.loc[lb2_2013['YEAR'] == '14', 'YEAR'] = 'latest'

# %%
lb2_2013
# Out:
#                                               ENTITY  YEAR RECORDS LOST  \
# 1                             Accendo Insurance Co.   2011      175,350
# 2                         Affinity Health Plan, Inc.  2009      344,579
# 3             Ankle & foot Center of Tampa Bay, Inc.  2010      156,000
# 4                                                AOL  2004   92,000,000
# 5                                                AOL  2006   20,000,000
# 6                                              Apple  2012  12,367,232
# 7                                              Apple  2013      275,000
# 8                                               AT&T  2008      113,000
# 9                                               AT&T  2010      114,000
# 10                                     Auction.co.kr  2008   18,000,000
# 11                         Automatic Data Processing  2005      125,000
# 12                                       AvMed, Inc.  2009    1,220,000
# 13                                           Betfair  2010    2,300,000
# 14                             Bethesda Game Studios  2011      200,000
# 15                                          Blizzard  2012   14,000,000
# 16               Blue Cross Blue Shield of Tennessee  2009    1,023,209
# 17                    BNY Mellon Shareowner Services  2008   12,500,000
# 18   California Department of Child Support Services  2012      800,000
# 19                       Cardsystems Solutions Inc.   2005   40,000,000
# 20                     Central Hudson Gas & Electric  2013      110,000
# 21                             CheckFree Corporation  2009    5,000,000
# 22                       Chile Ministry Of Education  2008    6,000,000
# 23                                         Citigroup  2005    3,900,000
# 24                                         Citigroup  2011      360,083
# 25                               Colorado government  2010      105,470
# 26                                      Compass Bank  2007    1,000,000
# 27                        Countrywide Financial Corp  2006    2,600,000
# 28                   Crescent Health Inc., Walgreens  2013      100,000
# 29                               Dai Nippon Printing  2007    8,637,405
# 30                     Data Processors International  2008    5,000,000
# ..                                               ...   ...          ...
# 94                                TerraCom & YourTel  2013      170,000
# 95                                     Texas Lottery  2007       89,000
# 96                               Three Iranian banks  2012    3,000,000
# 97                                      TK / TJ Maxx  2007   94,000,000
# 98                                           Tricare  2011    4,901,432
# 99                              Triple-S Salud, Inc.  2010      398,000
# 100                                          Twitter  2013      250,000
# 101                                          UbiSoft  2013      unknown
# 102                                           Ubuntu  2013    2,000,000
# 103                             UK Revenue & Customs  2007   25,000,000
# 104                University of California Berkeley  2009      160,000
# 105                              University of Miami  2008    2,100,000
# 106           University of Utah Hospitals & Clinics  2008    2,200,000
# 107              University of Wisconsin - Milwaukee  2011       73,000
# 108                                          US Army  2011       50,000
# 109                               US Dept of Defense  2009       72,000
# 110                           US Dept of Vet Affairs  2006   26,500,000
# 111             US Federal Reserve Bank of Cleveland  2010      400,000
# 112                               US Law Enforcement  2011      123,461
# 113                                      US Military  2009   76,000,000
# 114                                      US Military  2010      260,000
# 115                                US National Guard  2009      131,000
# 116                         Virginia Dept. Of Health  2009    8,257,378
# 117         Virginia Prescription Monitoring Program  2009      531,400
# 118                                  Washington Post  2011    1,270,000
# 119                    Washington State court system  2013      160,000
# 120                                  Writerspace.com  2011       62,000
# 121                                            Yahoo  2012      450,000
# 122                                            Yahoo  2013   22,000,000
# 123                                  Yale University  2010       43,000
#
#                ORGANISATION          METHOD OF LEAK DATA SENSITIVITY
# 1                healthcare           poor security                4
# 2                healthcare    lost / stolen media                 4
# 3                healthcare                  hacked                4
# 4                       web      inside job, hacked                1
# 5                       web  accidentally published                1
# 6              tech, retail  accidentally published                2
# 7                      tech                  hacked                1
# 8                  telecoms  lost / stolen computer                1
# 9                  telecoms                  hacked                1
# 10                      web                  hacked                3
# 11                financial           poor security                2
# 12               healthcare  lost / stolen computer             2, 4
# 13                      web                  hacked                3
# 14                   gaming                  hacked                1
# 15                   gaming                  hacked                2
# 16               healthcare    lost / stolen media                 2
# 17                financial    lost / stolen media                 1
# 18               government    lost / stolen media                 2
# 19                financial                  hacked                3
# 20                   energy                  hacked                3
# 21                financial                  hacked                1
# 22               government  accidentally published                1
# 23                financial    lost / stolen media                 3
# 24                financial                  hacked                3
# 25               healthcare  lost / stolen computer                2
# 26                financial              inside job                3
# 27                financial              inside job                3
# 28               healthcare  lost / stolen computer                4
# 29                   retail              inside job                1
# 30                financial                  hacked                1
# ..                      ...                     ...              ...
# 94                 telecoms  accidentally published                2
# 95               government              inside job                2
# 96                financial                  hacked                5
# 97                   retail                  hacked                3
# 98     military, healthcare  lost / stolen computer                4
# 99               healthcare     lost / stolen media                4
# 100                     web                 hacked                 1
# 101                  gaming                  hacked                2
# 102                    tech                  hacked                3
# 103              government    lost / stolen media                 1
# 104                academic                  hacked                3
# 105                academic  lost / stolen computer             3, 4
# 106                academic     lost / stolen media                4
# 107                academic                  hacked                2
# 108                military  accidentally published                1
# 109                military    lost / stolen media                 2
# 110    government, military  lost / stolen computer                2
# 111               financial                  hacked                3
# 112              government  accidentally published                3
# 113                military    lost / stolen media                 2
# 114                military  lost / stolen computer                5
# 115                military  lost / stolen computer                2
# 116  government, healthcare                  hacked                4
# 117              healthcare                  hacked                2
# 118                   media                  hacked                2
# 119              government                  hacked                2
# 120                     web                  hacked                1
# 121               tech, web                  hacked                1
# 122               tech, web                  hacked                1
# 123                academic  accidentally published                2
#
# [122 rows x 6 columns]

# %%
lb2_2013.loc[lb2_2013['DATA SENSITIVITY'] == '1', 'DATA SENSITIVITY'] = 'Just email address/Online information'
lb2_2013.loc[lb2_2013['DATA SENSITIVITY'] == '20', 'DATA SENSITIVITY'] = 'SSN/Personal details'
lb2_2013.loc[lb2_2013['DATA SENSITIVITY'] == '300', 'DATA SENSITIVITY'] = 'Credit card information'
lb2_2013.loc[lb2_2013['DATA SENSITIVITY'] == '4000', 'DATA SENSITIVITY'] = 'Email password/Health records'
lb2_2013.loc[lb2_2013['DATA SENSITIVITY'] == '50000', 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
lb2_2013
# Out:
#                                               ENTITY  YEAR RECORDS LOST  \
# 1                             Accendo Insurance Co.   2011      175,350
# 2                         Affinity Health Plan, Inc.  2009      344,579
# 3             Ankle & foot Center of Tampa Bay, Inc.  2010      156,000
# 4                                                AOL  2004   92,000,000
# 5                                                AOL  2006   20,000,000
# 6                                              Apple  2012  12,367,232
# 7                                              Apple  2013      275,000
# 8                                               AT&T  2008      113,000
# 9                                               AT&T  2010      114,000
# 10                                     Auction.co.kr  2008   18,000,000
# 11                         Automatic Data Processing  2005      125,000
# 12                                       AvMed, Inc.  2009    1,220,000
# 13                                           Betfair  2010    2,300,000
# 14                             Bethesda Game Studios  2011      200,000
# 15                                          Blizzard  2012   14,000,000
# 16               Blue Cross Blue Shield of Tennessee  2009    1,023,209
# 17                    BNY Mellon Shareowner Services  2008   12,500,000
# 18   California Department of Child Support Services  2012      800,000
# 19                       Cardsystems Solutions Inc.   2005   40,000,000
# 20                     Central Hudson Gas & Electric  2013      110,000
# 21                             CheckFree Corporation  2009    5,000,000
# 22                       Chile Ministry Of Education  2008    6,000,000
# 23                                         Citigroup  2005    3,900,000
# 24                                         Citigroup  2011      360,083
# 25                               Colorado government  2010      105,470
# 26                                      Compass Bank  2007    1,000,000
# 27                        Countrywide Financial Corp  2006    2,600,000
# 28                   Crescent Health Inc., Walgreens  2013      100,000
# 29                               Dai Nippon Printing  2007    8,637,405
# 30                     Data Processors International  2008    5,000,000
# ..                                               ...   ...          ...
# 94                                TerraCom & YourTel  2013      170,000
# 95                                     Texas Lottery  2007       89,000
# 96                               Three Iranian banks  2012    3,000,000
# 97                                      TK / TJ Maxx  2007   94,000,000
# 98                                           Tricare  2011    4,901,432
# 99                              Triple-S Salud, Inc.  2010      398,000
# 100                                          Twitter  2013      250,000
# 101                                          UbiSoft  2013      unknown
# 102                                           Ubuntu  2013    2,000,000
# 103                             UK Revenue & Customs  2007   25,000,000
# 104                University of California Berkeley  2009      160,000
# 105                              University of Miami  2008    2,100,000
# 106           University of Utah Hospitals & Clinics  2008    2,200,000
# 107              University of Wisconsin - Milwaukee  2011       73,000
# 108                                          US Army  2011       50,000
# 109                               US Dept of Defense  2009       72,000
# 110                           US Dept of Vet Affairs  2006   26,500,000
# 111             US Federal Reserve Bank of Cleveland  2010      400,000
# 112                               US Law Enforcement  2011      123,461
# 113                                      US Military  2009   76,000,000
# 114                                      US Military  2010      260,000
# 115                                US National Guard  2009      131,000
# 116                         Virginia Dept. Of Health  2009    8,257,378
# 117         Virginia Prescription Monitoring Program  2009      531,400
# 118                                  Washington Post  2011    1,270,000
# 119                    Washington State court system  2013      160,000
# 120                                  Writerspace.com  2011       62,000
# 121                                            Yahoo  2012      450,000
# 122                                            Yahoo  2013   22,000,000
# 123                                  Yale University  2010       43,000
#
#                ORGANISATION          METHOD OF LEAK  \
# 1                healthcare           poor security
# 2                healthcare    lost / stolen media
# 3                healthcare                  hacked
# 4                       web      inside job, hacked
# 5                       web  accidentally published
# 6              tech, retail  accidentally published
# 7                      tech                  hacked
# 8                  telecoms  lost / stolen computer
# 9                  telecoms                  hacked
# 10                      web                  hacked
# 11                financial           poor security
# 12               healthcare  lost / stolen computer
# 13                      web                  hacked
# 14                   gaming                  hacked
# 15                   gaming                  hacked
# 16               healthcare    lost / stolen media
# 17                financial    lost / stolen media
# 18               government    lost / stolen media
# 19                financial                  hacked
# 20                   energy                  hacked
# 21                financial                  hacked
# 22               government  accidentally published
# 23                financial    lost / stolen media
# 24                financial                  hacked
# 25               healthcare  lost / stolen computer
# 26                financial              inside job
# 27                financial              inside job
# 28               healthcare  lost / stolen computer
# 29                   retail              inside job
# 30                financial                  hacked
# ..                      ...                     ...
# 94                 telecoms  accidentally published
# 95               government              inside job
# 96                financial                  hacked
# 97                   retail                  hacked
# 98     military, healthcare  lost / stolen computer
# 99               healthcare     lost / stolen media
# 100                     web                 hacked
# 101                  gaming                  hacked
# 102                    tech                  hacked
# 103              government    lost / stolen media
# 104                academic                  hacked
# 105                academic  lost / stolen computer
# 106                academic     lost / stolen media
# 107                academic                  hacked
# 108                military  accidentally published
# 109                military    lost / stolen media
# 110    government, military  lost / stolen computer
# 111               financial                  hacked
# 112              government  accidentally published
# 113                military    lost / stolen media
# 114                military  lost / stolen computer
# 115                military  lost / stolen computer
# 116  government, healthcare                  hacked
# 117              healthcare                  hacked
# 118                   media                  hacked
# 119              government                  hacked
# 120                     web                  hacked
# 121               tech, web                  hacked
# 122               tech, web                  hacked
# 123                academic  accidentally published
#
#                           DATA SENSITIVITY
# 1                                        4
# 2                                        4
# 3                                        4
# 4    Just email address/Online information
# 5    Just email address/Online information
# 6                                        2
# 7    Just email address/Online information
# 8    Just email address/Online information
# 9    Just email address/Online information
# 10                                       3
# 11                                       2
# 12                                    2, 4
# 13                                       3
# 14   Just email address/Online information
# 15                                       2
# 16                                       2
# 17   Just email address/Online information
# 18                                       2
# 19                                       3
# 20                                       3
# 21   Just email address/Online information
# 22   Just email address/Online information
# 23                                       3
# 24                                       3
# 25                                       2
# 26                                       3
# 27                                       3
# 28                                       4
# 29   Just email address/Online information
# 30   Just email address/Online information
# ..                                     ...
# 94                                       2
# 95                                       2
# 96                                       5
# 97                                       3
# 98                                       4
# 99                                       4
# 100  Just email address/Online information
# 101                                      2
# 102                                      3
# 103  Just email address/Online information
# 104                                      3
# 105                                   3, 4
# 106                                      4
# 107                                      2
# 108  Just email address/Online information
# 109                                      2
# 110                                      2
# 111                                      3
# 112                                      3
# 113                                      2
# 114                                      5
# 115                                      2
# 116                                      4
# 117                                      2
# 118                                      2
# 119                                      2
# 120  Just email address/Online information
# 121  Just email address/Online information
# 122  Just email address/Online information
# 123                                      2
#
# [122 rows x 6 columns]

# %%
lb2_2013.to_csv('Data_2013.csv')
